# %%
import pandas as pd
import numpy as np
base = pd.read_csv("base_depurada2.csv",sep=",",encoding="latin-1")
base
# Out:
#              X       FECHA   ANO              CLASE          DIRECCION  \
# 0            1  2014-07-04  2014             Choque        CR 51 CL 53
# 1            2  2014-07-04  2014             Choque       CR 81 A CL 1
# 2            3  2014-07-04  2014             Choque        CL 10 CR 38
# 3            4  2014-07-04  2014             Choque    Tv 39 B CL 74 A
# 4            5  2014-07-04  2014             Choque        CR 70 CL 18
# ...        ...         ...   ...                ...                ...
# 249090  249091  2020-08-31  2020             Choque        CL 80 CR 65
# 249091  249092  2020-08-31  2020  Caida de Ocupante        CR 62 CL 59
# 249092  249093  2020-08-31  2020               Otro        CR 46 CL 52
# 249093  249094  2020-08-31  2020             Choque      CL 19 B CR 88
# 249094  249095  2020-08-31  2020             Choque  CL 58 CR 32 Norte
#
#               DISENO     GRAVEDAD  MES  NUMCOMUNA   LONGITUD   LATITUD  \
# ...

# %%
np.unique(base["DIA_SEMANA"])
# Out:
# array(['domingo', 'jueves', 'lunes', 'martes', 'miércoles', 'sábado',
#        'viernes'], dtype=object)

# %%
base.replace("miércoles","miercoles")
# Out:
#              X       FECHA   ANO              CLASE          DIRECCION  \
# 0            1  2014-07-04  2014             Choque        CR 51 CL 53
# 1            2  2014-07-04  2014             Choque       CR 81 A CL 1
# 2            3  2014-07-04  2014             Choque        CL 10 CR 38
# 3            4  2014-07-04  2014             Choque    Tv 39 B CL 74 A
# 4            5  2014-07-04  2014             Choque        CR 70 CL 18
# ...        ...         ...   ...                ...                ...
# 249090  249091  2020-08-31  2020             Choque        CL 80 CR 65
# 249091  249092  2020-08-31  2020  Caida de Ocupante        CR 62 CL 59
# 249092  249093  2020-08-31  2020               Otro        CR 46 CL 52
# 249093  249094  2020-08-31  2020             Choque      CL 19 B CR 88
# 249094  249095  2020-08-31  2020             Choque  CL 58 CR 32 Norte
#
#               DISENO     GRAVEDAD  MES  NUMCOMUNA   LONGITUD   LATITUD  \
# ...

# %%
base.replace("sábado","sabado")
# Out:
#              X       FECHA   ANO              CLASE          DIRECCION  \
# 0            1  2014-07-04  2014             Choque        CR 51 CL 53
# 1            2  2014-07-04  2014             Choque       CR 81 A CL 1
# 2            3  2014-07-04  2014             Choque        CL 10 CR 38
# 3            4  2014-07-04  2014             Choque    Tv 39 B CL 74 A
# 4            5  2014-07-04  2014             Choque        CR 70 CL 18
# ...        ...         ...   ...                ...                ...
# 249090  249091  2020-08-31  2020             Choque        CL 80 CR 65
# 249091  249092  2020-08-31  2020  Caida de Ocupante        CR 62 CL 59
# 249092  249093  2020-08-31  2020               Otro        CR 46 CL 52
# 249093  249094  2020-08-31  2020             Choque      CL 19 B CR 88
# 249094  249095  2020-08-31  2020             Choque  CL 58 CR 32 Norte
#
#               DISENO     GRAVEDAD  MES  NUMCOMUNA   LONGITUD   LATITUD  \
# ...

# %%
np.unique(base["DIA_SEMANA"])
# Out:
# array(['domingo', 'jueves', 'lunes', 'martes', 'miércoles', 'sábado',
#        'viernes'], dtype=object)

# %%
base.loc[base["DIA_SEMANA"] == "sábado","DIA_SEMANA"]="sabado"

# %%
base.loc[base["DIA_SEMANA"] == "miércoles","DIA_SEMANA"]="miercoles"

# %%
np.unique(base["DIA_SEMANA"])
# Out:
# array(['domingo', 'jueves', 'lunes', 'martes', 'miercoles', 'sabado',
#        'viernes'], dtype=object)

# %%
base.to_csv("base_depurada3.csv",encoding="UTF-8")
